# %% [markdown]
# # Evaluating scGPT NSCLC cell embeddings

# %% [markdown]
# This code imports necessary libraries, filters out certain types of warnings, and imports modules and custom logging objects for use in subsequent operations.

# %%
import pandas as pd

import scgpt
import flash_attn
import torch

import os
import logging
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

from sc_foundation_evals import cell_embeddings, scgpt_forward, data, model_output
from sc_foundation_evals.helpers.custom_logging import log

log.setLevel(logging.INFO)

# %% [markdown]
# ### Setting up variables

# %% [markdown]
# This code snippet sets up parameters and file paths for both evaluating a pre-trained scGPT model and processing single-cell genomics data using scGPT. The parameters and paths configure the scGPT model and prepare the 2k NSCLC scRNA-seq data for analysis and evaluation. Note that the label column is set to "batch" because the dataset consists of only one batch and one donor.

# %%
# path to the pre-trained model, 3 files are expected: 
# model_weights (best_model.pt), model args (args.json), and model vocab (vocab.json)
scGPT_dir = "/home/cog/nlandzaat/rep_learning_sc_foundation/scGPT_human-20231219T082236Z-001/scGPT_human"
# batch_size depends on available GPU memory; should be a multiple of 8
batch_size=24
# output_dir is the path to which the results should be saved
file_path_out_scGPT = "/home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/4. output/scGPT_NSCLC_donor_1"
# path to where we will store the embeddings and other evaluation outputs
model_out = os.path.join(file_path_out_scGPT, "model_outputs")
# if you can use multithreading specify num_workers
num_workers=0

# %%
input_bins=51
model_run="pretrained"
seed=7
n_hvg=1200
# maximum sequence of the input is controlled by max_seq_len, here I'm using the pretrained default
max_seq_len=1200

# %%
# specify the path to anndata object
dataset_path = "/home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/2.NSCLC notebooks/adata_donor_1.h5ad"
# in which column in adata.obs are gene names stored? if they are in index, the index will be copied to a column with this name
gene_col = "gene_symbols"
# batch column found in adata.obs
batch_col = "batch"
# where are labels stored in adata.obs? 
label_cols = "batch"
# where the raw counts are stored?
layer_key = "counts"
# are the values log_norm already?
log_norm = False

# %% [markdown]
# ### Loading model and data

# %% [markdown]
# This code sets up and initializes a scGPT model for analyzing single-cell genomics data. First, it creates the model instance using parameters such as the path to the saved model, batch size, and file paths for saving results. Then, it generates configuration settings including the random seed, maximum sequence length, and the number of input bins. Next, the pre-trained model is loaded. The log will indicate that some weights cannot be loaded; however, this is acceptable as long as they are prefixed with "cls_". These layers are not utilized, since we are evaluating the model in a zero-shot setting.
# Next, an InputData object is created to handle the single-cell genomics dataset, specifying the path to the dataset file. Finally, the vocabulary list of the scGPT model is extracted for further processing.

# %%
# create scGPT instance
scgpt_model = scgpt_forward.scGPT_instance(saved_model_path = scGPT_dir,
                                           model_run = model_run,
                                           batch_size = batch_size, 
                                           save_dir = file_path_out_scGPT,
                                           num_workers = num_workers, 
                                           explicit_save_dir = True)
# Out:
# INFO     | 2024-04-02 08:56:31 | Using device cuda

# %%
# create config
scgpt_model.create_configs(seed = seed, 
                           max_seq_len = max_seq_len, 
                           n_bins = input_bins)

# %%
# load pretrained model
scgpt_model.load_pretrained_model()
# Out:
# WARNING  | 2024-04-02 08:56:31 | Overriding pre-trained config['save_dir'] with /home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/4. output/scGPT_NSCLC_donor_1 (was /scratch/ssd004/datasets/cellxgene/save/cellxgene_census_human-May23-08-36-2023)
# WARNING  | 2024-04-02 08:56:31 | Overriding pre-trained config['max_seq_len'] with 1200 (was 1200)
# INFO     | 2024-04-02 08:56:31 | Loading vocab from /home/cog/nlandzaat/rep_learning_sc_foundation/scGPT_human-20231219T082236Z-001/scGPT_human/vocab.json
# INFO     | 2024-04-02 08:56:32 | Loading model from /home/cog/nlandzaat/rep_learning_sc_foundation/scGPT_human-20231219T082236Z-001/scGPT_human/best_model.pt
# WARNING  | 2024-04-02 08:56:32 | Loading partial model params from /home/cog/nlandzaat/rep_learning_sc_foundation/scGPT_human-20231219T082236Z-001/scGPT_human/best_model.pt
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.0.weight with shape torch.Size([512, 512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.0.bias with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.2.weight with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.2.bias with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.3.weight with shape torch.Size([512, 512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.3.bias with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.5.weight with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder._decoder.5.bias with shape torch.Size([512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder.out_layer.weight with shape torch.Size([1, 512])
# WARNING  | 2024-04-02 08:56:32 | Cannot load cls_decoder.out_layer.bias with shape torch.Size([1])

# %%
# create input data object
input_data = data.InputData(adata_dataset_path = dataset_path)
# Out:
# INFO     | 2024-04-02 08:56:32 | Loading data from /home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/2.NSCLC notebooks/adata_donor_1.h5ad

# %%
# load vocabulary
vocab_list = scgpt_model.vocab.get_stoi().keys()

# %% [markdown]
# The input data undergoes preprocessing to prepare it for further analysis using the scGPT model. The purpose is to transform raw single-cell genomics data into a format suitable for input into the scGPT model. This involves tasks such as data normalization, binning, and identifying highly variable genes. Subsequently, the preprocessed data is tokenized, converting it into individual tokens or units which makes the format compatible with the scGPT model's input requirements.

# %%
# preprocessing as written in the scGPT repository, filter for the 1200 highly variable genes 

input_data.preprocess_data(gene_vocab = vocab_list,
                           model_type = "scGPT",
                           gene_col = gene_col,
                           data_is_raw = not log_norm,
                           counts_layer = layer_key, 
                           n_bins = input_bins,
                           n_hvg = n_hvg)
# Out:
# WARNING  | 2024-04-02 08:56:33 | Gene names not found in var columns. Using index instead.
# INFO     | 2024-04-02 08:56:33 | Matched 24285/36601 genes in vocabulary of size 60697.
# INFO     | 2024-04-02 08:56:33 | Preprocessing data
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Log1p transforming ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - WARNING - No batch_key is provided, will use all cells for HVG selection.
# scGPT - INFO - Binning data ...

# %%
# tokenize data
scgpt_model.tokenize_data(data = input_data,
                          input_layer_key = "X_binned",
                          include_zero_genes = False)
# Out:
# INFO     | 2024-04-02 08:56:34 | Tokenizing data

# %% [markdown]
# ### Evaluating embeddings

# %% [markdown]
# This code evaluates scGPT model embeddings on single-cell genomics data. It conducts a forward pass to extract embeddings, then assesses their performance in MLM and MVC tasks. Finally, it visualizes the embeddings with a 2D UMAP plot.

# %%
# forward pass on model and extract embeddings
scgpt_model.extract_embeddings(data = input_data)
# Out:
# INFO     | 2024-04-02 08:56:34 | Preparing dataloader
# INFO     | 2024-04-02 08:56:34 | Saving config to /home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/4. output/scGPT_NSCLC_donor_1
# INFO     | 2024-04-02 08:56:34 | Extracting embeddings
# INFO     | 2024-04-02 08:56:34 | Extracting embeddings for batch 1/80
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 2
#       1 # forward pass on model and extract embeddings
# ----> 2 scgpt_model.extract_embeddings(data = input_data)
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/sc_foundation_evals/scgpt_forward.py:758, in scGPT_instance.extract_embeddings(self, data, embedding_key, experimental)
#     755     log.info(msg)
#     757 with torch.no_grad() and torch.cuda.amp.autocast(enabled=self.model_config['amp']):
# --> 758     output_dict = self.model(
#     759         input_gene_ids,
#     760         input_values,
#     761         src_key_padding_mask = src_key_padding_mask,
#     762         batch_labels = batch_labels if self.model_config["use_batch_labels"] else None,
#     763         # gene expression prediction from cell embedding? GEPC
#     764         MVC = self.model_config["do_mvc"],
#     765         # elastic cell similarity
#     766         ECS = self.model_config["do_ecs"],
#     767         # cell type classification objective
#     768         CLS = self.model_config["do_cls"],
#     769         # contrastive cell embedding objective
#     770         CCE = self.model_config["do_cce"]
#     771     )
#     773     # revert order, so that it works with down stream tasks
#     774     if self.run_config["permute_gene_order"]:
#     775         # inputs
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/scgpt/model/model.py:345, in TransformerModel.forward(self, src, values, src_key_padding_mask, batch_labels, CLS, CCE, MVC, ECS, do_sample)
#     314 def forward(
#     315     self,
#     316     src: Tensor,
#    (...)
#     324     do_sample: bool = False,
#     325 ) -> Mapping[str, Tensor]:
#     326     """
#     327     Args:
#     328         src (:obj:`Tensor`): token ids, shape [batch_size, seq_len]
#    (...)
#     343         dict of output Tensors.
#     344     """
# --> 345     transformer_output = self._encode(
#     346         src, values, src_key_padding_mask, batch_labels
#     347     )
#     348     if self.use_batch_labels:
#     349         batch_emb = self.batch_encoder(batch_labels)  # (batch, embsize)
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/scgpt/model/model.py:194, in TransformerModel._encode(self, src, values, src_key_padding_mask, batch_labels)
#     191 elif getattr(self, "bn", None) is not None:
#     192     total_embs = self.bn(total_embs.permute(0, 2, 1)).permute(0, 2, 1)
# --> 194 output = self.transformer_encoder(
#     195     total_embs, src_key_padding_mask=src_key_padding_mask
#     196 )
#     197 return output
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/transformer.py:280, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask)
#     277         src_key_padding_mask_for_layers = None
#     279 for mod in self.layers:
# --> 280     output = mod(output, src_mask=mask, src_key_padding_mask=src_key_padding_mask_for_layers)
#     282 if convert_to_nested:
#     283     output = output.to_padded_tensor(0.)
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/scgpt/model/model.py:710, in FlashTransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, **kwargs)
#     708     src = src + self.dropout2(src2)
#     709 else:
# --> 710     src2 = self.self_attn(src, key_padding_mask=src_key_padding_mask_)[0]
#     711     src = src + self.dropout1(src2)
#     712     src = self.norm1(src)
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/flash_attn/flash_attention.py:99, in FlashMHA.forward(self, x, key_padding_mask, need_weights)
#      97 qkv = self.Wqkv(x)
#      98 qkv = rearrange(qkv, 'b s (three h d) -> b s three h d', three=3, h=self.num_heads)
# ---> 99 context, attn_weights = self.inner_attn(qkv, key_padding_mask=key_padding_mask,
#     100                                         need_weights=need_weights, causal=self.causal)
#     101 return self.out_proj(rearrange(context, 'b s h d -> b s (h d)')), attn_weights
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/flash_attn/flash_attention.py:57, in FlashAttention.forward(self, qkv, key_padding_mask, causal, cu_seqlens, max_s, need_weights)
#      55         x_unpad, indices, cu_seqlens, max_s = unpad_input(x, key_padding_mask)
#      56         x_unpad = rearrange(x_unpad, 'nnz (three h d) -> nnz three h d', three=3, h=nheads)
# ---> 57         output_unpad = flash_attn_unpadded_qkvpacked_func(
#      58             x_unpad, cu_seqlens, max_s, self.dropout_p if self.training else 0.0,
#      59             softmax_scale=self.softmax_scale, causal=causal
#      60         )
#      61         output = rearrange(pad_input(rearrange(output_unpad, 'nnz h d -> nnz (h d)'),
#      62                                     indices, batch_size, seqlen),
#      63                         'b s (h d) -> b s h d', h=nheads)
#      64 else:
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/flash_attn/flash_attn_interface.py:256, in flash_attn_unpadded_qkvpacked_func(qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale, causal, return_attn_probs, deterministic)
#     231 def flash_attn_unpadded_qkvpacked_func(qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale=None,
#     232                                        causal=False, return_attn_probs=False, deterministic=False):
#     233     """dropout_p should be set to 0.0 during evaluation
#     234     Arguments:
#     235         qkv: (total, 3, nheads, headdim), where total = total number of tokens in the batch.
#    (...)
#     254             pattern (negative means that location was dropped, nonnegative means it was kept).
#     255     """
# --> 256     return FlashAttnQKVPackedFunc.apply(qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale,
#     257                                         causal, return_attn_probs, deterministic)
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/flash_attn/flash_attn_interface.py:58, in FlashAttnQKVPackedFunc.forward(ctx, qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale, causal, return_softmax, deterministic)
#      56 if softmax_scale is None:
#      57     softmax_scale = qkv.shape[-1] ** (-0.5)
# ---> 58 out, softmax_lse, rng_state, S_dmask = _flash_attn_forward(
#      59     qkv[:, 0], qkv[:, 1], qkv[:, 2], torch.empty_like(qkv[:, 0]), cu_seqlens, cu_seqlens,
#      60     max_seqlen, max_seqlen, dropout_p, softmax_scale, causal=causal,
#      61     return_softmax=return_softmax
#      62 )
#      63 ctx.save_for_backward(qkv, out, softmax_lse, cu_seqlens, rng_state)
#      64 ctx.dropout_p = dropout_p
#
# File /hpc/compgen/users/nlandzaat/Software/anaconda3/envs/project_env_test/lib/python3.9/site-packages/flash_attn/flash_attn_interface.py:21, in _flash_attn_forward(q, k, v, out, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p, softmax_scale, causal, return_softmax, num_splits, generator)
#      13 def _flash_attn_forward(q, k, v, out, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k,
#      14                         dropout_p, softmax_scale, causal, return_softmax, num_splits=0,
#      15                         generator=None):
#      16     """
#      17     num_splits: how much to parallelize over the seqlen_q dimension. num_splits=0 means
#      18     it will be set by an internal heuristic. We're exposing num_splits mostly for benchmarking.
#      19     Don't change it unless you know what you're doing.
#      20     """
# ---> 21     softmax_lse, rng_state, *rest = flash_attn_cuda.fwd(
#      22         q, k, v, out, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p,
#      23         softmax_scale, False, causal, return_softmax, num_splits, generator
#      24     )
#      25     # if out.isnan().any() or softmax_lse.isnan().any():
#      26     #     breakpoint()
#      27     S_dmask = rest[0] if return_softmax else None
#
# RuntimeError: Expected is_sm90 || is_sm8x || is_sm75 to be true, but got false.  (Could this error message be improved?  If so, please report an enhancement request to PyTorch.)

# %%
# save embeddings to a DataFrame
scGPT_embeddings_df = pd.DataFrame(scgpt_model.cell_embeddings)

# save the DataFrame with embeddings to a CSV file
scGPT_embedding_file_path = "/home/cog/nlandzaat/rep_learning_sc_foundation/analysis/nlandzaat/4. output/scGPT_embeddings_NSCLC.csv"
scGPT_embeddings_df.to_csv(scGPT_embedding_file_path, index=False)

# %%
# evaluate mlm (masked language modeling) and mvc (multi-view clustering a.k.a. gene expression prediction from cell embedding) output
eval_pred = model_output.GeneExprPredEval(scgpt_model,
                                         data = input_data,
                                         output_dir = model_out,
                                         embedding_key = ["mlm_output", 
                                                          "mvc_output"])

# %%
eval_pred.evaluate()
# Out:
# WARNING  | 2024-03-20 15:46:40 | mlm_output is not a tensor
# WARNING  | 2024-03-20 15:46:40 | mvc_output is not a tensor
#                    MSE     MSE_all       MRE   MRE_all        MAE    MAE_all
# mlm_output  241.090454  241.090454  0.432272  0.432272  13.236105  13.236105
# mvc_output  180.540863  180.540863  0.464937  0.464937  11.374786  11.374786
# mean        203.564789  203.564789  0.488338  0.488338  12.364139  12.364139

# %%
eval_ce = cell_embeddings.CellEmbeddingsEval(scgpt_model,
                                             data = input_data,
                                             output_dir = model_out,
                                             label_key = label_cols,
                                             batch_key = batch_col)

# %%
# visualize embeddings
eval_ce.visualize(plot_title = "UMAP of the NSCLC cell embeddings by scGPT")
